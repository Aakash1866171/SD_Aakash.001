# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakash1866171/SD_Aakash.001/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    "name": "vikas",
    "age": 20,
    "grade": "A"
}

print(student)
# Out:
# {'name': 'vikas', 'age': 20, 'grade': 'A'}

# %%
student = {
    "name": "Alice",
    "age": 20,
    "grade": "A"
}


print("Keys:")
for key in student.keys():
    print(key)


print("\nValues:")
for value in student.values():
    print(value)
# Out:
# Keys:
# name
# age
# grade
#
# Values:
# Alice
# 20
# A
