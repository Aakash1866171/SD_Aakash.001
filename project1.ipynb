# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakash1866171/SD_Aakash.001/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = []

while True:
    print("\n===== Student Management System =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        name = input("Enter name: ")
        age = int(input("Enter age: "))
        grade = input("Enter grade: ")

        students.append([name, age, grade])
        print("Student added successfully!")

    elif choice == 2:
        if len(students) == 0:
            print("No students found!")
        else:
            for i in range(len(students)):
                print(i + 1, students[i][0], "-", students[i][1], "-", students[i][2])

    elif choice == 3:
        search = input("Enter name to search: ")
        found = False

        for s in students:
            if s[0].lower() == search.lower():
                print("Found:", s[0], s[1], s[2])
                found = True
                break

        if not found:
            print("Student not found!")

    elif choice == 4:
        print("Exiting...")
        break

    else:
        print("Invalid choice")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# Enter your choice: 1
# Enter name: vikas
# Enter age: 35
# Enter grade: 7.7
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# Enter your choice: 1
# Enter name: abhay
# Enter age: 23
# Enter grade: 8.3
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# Enter your choice: 3
# Enter name to search: abhay
# Found: abhay 23 8.3
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# Enter your choice: 3
# Enter name to search: vikas
# Found: vikas 35 7.7
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# Enter your choice: 1
# Enter name: agam
# Enter age: 22
# Enter grade: 7.55
# ...
